# %% [markdown]
# # INSTRUÇÃO PRÁTICA - IP-P007
# ## Revisam e consolidaçao do conteúdo de __Pandas__ avançado.

# %% [markdown]
# ### __Exercício 1: Carregando e analisando um DataSet__
#
# Dados de estações metereologicas por ano: [Instituto Nacional de Meteorologia](https://portal.inmet.gov.br/dadoshistoricos).
# 1. Download de dados de 2003, 2013 e 2023 da estação Salvador.
# 2. Carregando e analizando dados das três estações em ``DataFrame``s separados.

# %%
import pandas as pd

# carregando os aquivos csv
estacao_ssa_2003 = pd.read_csv('../datasets/estacao_Salvador_2003.csv', sep=";", header=8, encoding='latin-1')
estacao_ssa_2013 = pd.read_csv('../datasets/estacao_Salvador_2013.csv', sep=",", header=8, encoding='utf-8')
estacao_ssa_2023 = pd.read_csv('../datasets/estacao_Salvador_2023.csv', sep=";", header=8, encoding='latin-1')

# %%
# estacao em 2003
estacao_ssa_2003.info()
estacao_ssa_2003.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 20 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   DATA (YYYY-MM-DD)                                      8760 non-null   object
#  1   HORA (UTC)                                             8760 non-null   object
#  2   PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                       8760 non-null   object
#  3   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  8760 non-null   object
#  4   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        8760 non-null   object
#  5   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       8760 non-null   object
#  6   RADIACAO GLOBAL (KJ/m²)                                8760 non-null   int64
#  7   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)           8760 non-null   object
#  8   TEMPERATURA DO PONTO DE ORVALHO (°C)                   8760 non-null   object
#  9   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)             8760 non-null   object
#  10  TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)             8760 non-null   object
#  11  TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)       8760 non-null   object
#  12  TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)       8760 non-null   object
#  13  UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)               8760 non-null   int64
#  14  UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)               8760 non-null   int64
#  15  UMIDADE RELATIVA DO AR, HORARIA (%)                    8760 non-null   int64
#  16  VENTO, DIREÇÃO HORARIA (gr) (° (gr))                   8760 non-null   int64
#  17  VENTO, RAJADA MAXIMA (m/s)                             8760 non-null   object
#  18  VENTO, VELOCIDADE HORARIA (m/s)                        8760 non-null   object
#  19  Unnamed: 19                                            0 non-null      float64
# dtypes: float64(1), int64(5), object(14)
# memory usage: 1.3+ MB
#   DATA (YYYY-MM-DD) HORA (UTC) PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# 0        2003-01-01      00:00                            -9999  \
# 1        2003-01-01      01:00                            -9999
# 2        2003-01-01      02:00                            -9999
# 3        2003-01-01      03:00                            -9999
# 4        2003-01-01      04:00                            -9999
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)
# 0                                              -9999     \
# 1                                              -9999
# 2                                              -9999
# 3                                              -9999
# 4                                              -9999
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)
# 0                                           -9999  \
# 1                                           -9999
# 2                                           -9999
# 3                                           -9999
# 4                                           -9999
#
#   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  RADIACAO GLOBAL (KJ/m²)
# 0                                            -9999                    -9999  \
# 1                                            -9999                    -9999
# 2                                            -9999                    -9999
# 3                                            -9999                    -9999
# 4                                            -9999                    -9999
#
#   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)
# 0                                        -9999  \
# 1                                        -9999
# 2                                        -9999
# 3                                        -9999
# 4                                        -9999
#
#   TEMPERATURA DO PONTO DE ORVALHO (°C)
# 0                                -9999  \
# 1                                -9999
# 2                                -9999
# 3                                -9999
# 4                                -9999
#
#   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)
# 0                                      -9999  \
# 1                                      -9999
# 2                                      -9999
# 3                                      -9999
# 4                                      -9999
#
#   TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)
# 0                                      -9999  \
# 1                                      -9999
# 2                                      -9999
# 3                                      -9999
# 4                                      -9999
#
#   TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)
# 0                                            -9999  \
# 1                                            -9999
# 2                                            -9999
# 3                                            -9999
# 4                                            -9999
#
#   TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)
# 0                                            -9999  \
# 1                                            -9999
# 2                                            -9999
# 3                                            -9999
# 4                                            -9999
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)
# 0                                     -9999  \
# 1                                     -9999
# 2                                     -9999
# 3                                     -9999
# 4                                     -9999
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)
# 0                                     -9999  \
# 1                                     -9999
# 2                                     -9999
# 3                                     -9999
# 4                                     -9999
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))
# 0                                -9999                                 -9999  \
# 1                                -9999                                 -9999
# 2                                -9999                                 -9999
# 3                                -9999                                 -9999
# 4                                -9999                                 -9999
#
#   VENTO, RAJADA MAXIMA (m/s) VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 0                      -9999                           -9999          NaN
# 1                      -9999                           -9999          NaN
# 2                      -9999                           -9999          NaN
# 3                      -9999                           -9999          NaN
# 4                      -9999                           -9999          NaN

# %%
# estacao em 2013
estacao_ssa_2013.info()
estacao_ssa_2013.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 19 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   DATA (YYYY-MM-DD)                                      8760 non-null   object
#  1   HORA (UTC)                                             8760 non-null   object
#  2   PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                       8760 non-null   object
#  3   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  8760 non-null   object
#  4   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        8760 non-null   object
#  5   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       8760 non-null   object
#  6   RADIACAO GLOBAL (KJ/m²)                                8760 non-null   object
#  7   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)           8760 non-null   object
#  8   TEMPERATURA DO PONTO DE ORVALHO (°C)                   8760 non-null   object
#  9   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)             8760 non-null   object
#  10  TEMPERATURA M�NIMA NA HORA ANT. (AUT) (�C)             8760 non-null   object
#  11  TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)       8760 non-null   object
#  12  TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)       8760 non-null   object
#  13  UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)               8760 non-null   int64
#  14  UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)               8760 non-null   int64
#  15  UMIDADE RELATIVA DO AR, HORARIA (%)                    8760 non-null   int64
#  16  VENTO, DIREÇÃO HORARIA (gr) (° (gr))                   8760 non-null   int64
#  17  VENTO, RAJADA MAXIMA (m/s)                             8760 non-null   object
#  18  VENTO, VELOCIDADE HORARIA (m/s)                        8760 non-null   object
# dtypes: int64(4), object(15)
# memory usage: 1.3+ MB
#   DATA (YYYY-MM-DD) HORA (UTC) PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# 0        2013-01-01      00:00                                0  \
# 1        2013-01-01      01:00                                0
# 2        2013-01-01      02:00                                0
# 3        2013-01-01      03:00                                0
# 4        2013-01-01      04:00                                0
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)
# 0                                             1008,3     \
# 1                                             1008,5
# 2                                             1008,4
# 3                                               1008
# 4                                             1007,3
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)
# 0                                          1008,3  \
# 1                                          1008,5
# 2                                          1008,5
# 3                                          1008,4
# 4                                            1008
#
#   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (KJ/m²)
# 0                                             1008                   -9999  \
# 1                                           1008,2                   -9999
# 2                                           1008,4                   -9999
# 3                                             1008                   -9999
# 4                                           1007,3                   -9999
#
#   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)
# 0                                         25,7  \
# 1                                         25,8
# 2                                         25,3
# 3                                         25,3
# 4                                         25,1
#
#   TEMPERATURA DO PONTO DE ORVALHO (°C)
# 0                                   22  \
# 1                                 21,9
# 2                                 21,9
# 3                                 21,5
# 4                                 21,4
#
#   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)
# 0                                       25,8  \
# 1                                       25,9
# 2                                       25,8
# 3                                       25,5
# 4                                       25,5
#
#   TEMPERATURA M�NIMA NA HORA ANT. (AUT) (�C)
# 0                                       25,5  \
# 1                                       25,4
# 2                                       25,1
# 3                                       25,2
# 4                                       25,1
#
#   TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)
# 0                                             22,1  \
# 1                                             22,1
# 2                                             21,9
# 3                                             21,9
# 4                                             21,6
#
#   TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)
# 0                                             21,6  \
# 1                                             21,6
# 2                                               21
# 3                                             21,4
# 4                                             21,4
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)
# 0                                        80  \
# 1                                        80
# 2                                        81
# 3                                        81
# 4                                        80
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)
# 0                                        78  \
# 1                                        79
# 2                                        78
# 3                                        79
# 4                                        79
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))
# 0                                   80                                    97  \
# 1                                   79                                    96
# 2                                   81                                   103
# 3                                   80                                    85
# 4                                   80                                    62
#
#   VENTO, RAJADA MAXIMA (m/s) VENTO, VELOCIDADE HORARIA (m/s)
# 0                        5,1                             1,5
# 1                        5,4                             1,8
# 2                        4,5                             1,3
# 3                        5,1                             1,3
# 4                        5,5                             1,1

# %%
# estacao em 2023
estacao_ssa_2023.info()
estacao_ssa_2023.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 20 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Data                                                   8760 non-null   object
#  1   Hora UTC                                               8760 non-null   object
#  2   PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                       8756 non-null   object
#  3   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  8756 non-null   object
#  4   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        8756 non-null   object
#  5   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       8756 non-null   object
#  6   RADIACAO GLOBAL (Kj/m²)                                4735 non-null   object
#  7   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)           8756 non-null   object
#  8   TEMPERATURA DO PONTO DE ORVALHO (°C)                   8756 non-null   object
#  9   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)             8756 non-null   object
#  10  TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)             8756 non-null   object
#  11  TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)       8756 non-null   object
#  12  TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)       8756 non-null   object
#  13  UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)               8756 non-null   float64
#  14  UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)               8756 non-null   float64
#  15  UMIDADE RELATIVA DO AR, HORARIA (%)                    8756 non-null   float64
#  16  VENTO, DIREÇÃO HORARIA (gr) (° (gr))                   8756 non-null   float64
#  17  VENTO, RAJADA MAXIMA (m/s)                             8756 non-null   object
#  18  VENTO, VELOCIDADE HORARIA (m/s)                        8756 non-null   object
#  19  Unnamed: 19                                            0 non-null      float64
# dtypes: float64(5), object(15)
# memory usage: 1.3+ MB
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# 0  2023/01/01  0000 UTC                                0  \
# 1  2023/01/01  0100 UTC                                0
# 2  2023/01/01  0200 UTC                                0
# 3  2023/01/01  0300 UTC                                0
# 4  2023/01/01  0400 UTC                              3,4
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)
# 0                                             1009,2     \
# 1                                             1009,4
# 2                                             1009,1
# 3                                             1008,5
# 4                                             1008,1
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)
# 0                                          1009,2  \
# 1                                          1009,4
# 2                                          1009,4
# 3                                          1009,1
# 4                                          1008,5
#
#   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)
# 0                                           1008,8                     NaN  \
# 1                                           1009,2                     NaN
# 2                                           1009,1                     NaN
# 3                                           1008,5                     NaN
# 4                                           1008,1                     NaN
#
#   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)
# 0                                         26,2  \
# 1                                         26,1
# 2                                           26
# 3                                         25,8
# 4                                         23,7
#
#   TEMPERATURA DO PONTO DE ORVALHO (°C)
# 0                                 21,8  \
# 1                                   22
# 2                                   22
# 3                                 21,9
# 4                                 21,7
#
#   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)
# 0                                       26,3  \
# 1                                       26,3
# 2                                       26,3
# 3                                         26
# 4                                       25,8
#
#   TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)
# 0                                       26,1  \
# 1                                         26
# 2                                         26
# 3                                       25,6
# 4                                       23,7
#
#   TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)
# 0                                               22  \
# 1                                               22
# 2                                             22,3
# 3                                             22,1
# 4                                             22,1
#
#   TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)
# 0                                             21,7  \
# 1                                             21,8
# 2                                               22
# 3                                             21,8
# 4                                             21,6
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)
# 0                                      78.0  \
# 1                                      78.0
# 2                                      79.0
# 3                                      80.0
# 4                                      89.0
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)
# 0                                      77.0  \
# 1                                      76.0
# 2                                      78.0
# 3                                      79.0
# 4                                      79.0
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))
# 0                                 77.0                                  77.0  \
# 1                                 78.0                                  90.0
# 2                                 79.0                                  79.0
# 3                                 79.0                                  84.0
# 4                                 89.0                                  52.0
#
#   VENTO, RAJADA MAXIMA (m/s) VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 0                        4,7                             1,3          NaN
# 1                        4,7                               1          NaN
# 2                          5                              ,9          NaN
# 3                        4,8                               1          NaN
# 4                        4,6                             1,4          NaN

# %% [markdown]
# * Limpando e unificando colunas para os três ``DataFrame``s.

# %%
# removendo colunas extraas
estacao_ssa_2003.drop(columns=['Unnamed: 19'], inplace=True)
estacao_ssa_2023.drop(columns=['Unnamed: 19'], inplace=True)

# %%
# unificando os dataframes
print("Colunas antes:")
colunas_2003 = estacao_ssa_2003.columns.values.tolist()
colunas_2013 = estacao_ssa_2013.columns.values.tolist()
colunas_2023 = estacao_ssa_2023.columns.values.tolist()

print(colunas_2003)
print(colunas_2013)
print(colunas_2023)

# renomeando colunas diferentes
print("\nColunas diferentes:")
for c_2003, c_2013, c_2023 in zip(colunas_2003, colunas_2013, colunas_2023):
    if c_2003 != c_2013 or c_2003 != c_2023:
        print(f"'{c_2003}' | '{c_2013}' | '{c_2023}'")
        estacao_ssa_2013.rename(columns={c_2013: c_2003}, inplace=True)
        estacao_ssa_2023.rename(columns={c_2023: c_2003}, inplace=True)


# imprimindo colunas depois
print("\nColunas depois:")
colunas_2003 = estacao_ssa_2003.columns.values.tolist()
colunas_2013 = estacao_ssa_2013.columns.values.tolist()
colunas_2023 = estacao_ssa_2023.columns.values.tolist()

print(colunas_2003)
print(colunas_2013)
print(colunas_2023)
# Out:
# Colunas antes:
# ['DATA (YYYY-MM-DD)', 'HORA (UTC)', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)', 'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)', 'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)', 'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)', 'RADIACAO GLOBAL (KJ/m²)', 'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)', 'TEMPERATURA DO PONTO DE ORVALHO (°C)', 'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)', 'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)', 'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)', 'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)', 'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)', 'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)', 'UMIDADE RELATIVA DO AR, HORARIA (%)', 'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 'VENTO, RAJADA MAXIMA (m/s)', 'VENTO, VELOCIDADE HORARIA (m/s)']
# ['DATA (YYYY-MM-DD)', 'HORA (UTC)', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)', 'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)', 'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)', 'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)', 'RADIACAO GLOBAL (KJ/m²)', 'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)', 'TEMPERATURA DO PONTO DE ORVALHO (°C)', 'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)', 'TEMPERATURA M�NIMA NA HORA ANT. (AUT) (�C)', 'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)', 'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)', 'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)', 'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)', 'UMIDADE RELATIVA DO AR, HORARIA (%)', 'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 'VENTO, RAJADA MAXIMA (m/s)', 'VENTO, VELOCIDADE HORARIA (m/s)']
# ['Data', 'Hora UTC', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)', 'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)', 'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)', 'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)', 'RADIACAO GLOBAL (Kj/m²)', 'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)', 'TEMPERATURA DO PONTO DE ORVALHO (°C)', 'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)', 'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)', 'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)', 'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)', 'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)', 'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)', 'UMIDADE RELATIVA DO AR, HORARIA (%)', 'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 'VENTO, RAJADA MAXIMA (m/s)', 'VENTO, VELOCIDADE HORARIA (m/s)']
#
# Colunas diferentes:
# 'DATA (YYYY-MM-DD)' | 'DATA (YYYY-MM-DD)' | 'Data'
# 'HORA (UTC)' | 'HORA (UTC)' | 'Hora UTC'
# 'RADIACAO GLOBAL (KJ/m²)' | 'RADIACAO GLOBAL (KJ/m²)' | 'RADIACAO GLOBAL (Kj/m²)'
# 'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)' | 'TEMPERATURA M�NIMA NA HORA ANT. (AUT) (�C)' | 'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)'
#
# Colunas depois:
# ['DATA (YYYY-MM-DD)', 'HORA (UTC)', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)', 'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)', 'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)', 'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)', 'RADIACAO GLOBAL (KJ/m²)', 'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)', 'TEMPERATURA DO PONTO DE ORVALHO (°C)', 'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)', 'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)', 'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)', 'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)', 'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)', 'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)', 'UMIDADE RELATIVA DO AR, HORARIA (%)', 'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 'VENTO, RAJADA MAXIMA (m/s)', 'VENTO, VELOCIDADE HORARIA (m/s)']
# ['DATA (YYYY-MM-DD)', 'HORA (UTC)', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)', 'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)', 'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)', 'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)', 'RADIACAO GLOBAL (KJ/m²)', 'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)', 'TEMPERATURA DO PONTO DE ORVALHO (°C)', 'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)', 'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)', 'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)', 'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)', 'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)', 'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)', 'UMIDADE RELATIVA DO AR, HORARIA (%)', 'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 'VENTO, RAJADA MAXIMA (m/s)', 'VENTO, VELOCIDADE HORARIA (m/s)']
# ['DATA (YYYY-MM-DD)', 'HORA (UTC)', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)', 'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)', 'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)', 'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)', 'RADIACAO GLOBAL (KJ/m²)', 'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)', 'TEMPERATURA DO PONTO DE ORVALHO (°C)', 'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)', 'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)', 'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)', 'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)', 'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)', 'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)', 'UMIDADE RELATIVA DO AR, HORARIA (%)', 'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 'VENTO, RAJADA MAXIMA (m/s)', 'VENTO, VELOCIDADE HORARIA (m/s)']

# %% [markdown]
# ### __Exercício 2: Juntando os datasets__
#
# 1. Constrindo um novo ``DataFrame`` utilizando um ``MultiIndex``.

# %%
# convertendo a coluna data para o tipo datetime
estacao_ssa_2003['DATA (YYYY-MM-DD)'] = pd.to_datetime(estacao_ssa_2003['DATA (YYYY-MM-DD)'])
estacao_ssa_2013['DATA (YYYY-MM-DD)'] = pd.to_datetime(estacao_ssa_2013['DATA (YYYY-MM-DD)'])
estacao_ssa_2023['DATA (YYYY-MM-DD)'] = pd.to_datetime(estacao_ssa_2023['DATA (YYYY-MM-DD)'])


# pegando listas com os anos, meses e dias de cada dataframe
anos = pd.concat([estacao_ssa_2003['DATA (YYYY-MM-DD)'].dt.year,
                  estacao_ssa_2013['DATA (YYYY-MM-DD)'].dt.year,
                  estacao_ssa_2023['DATA (YYYY-MM-DD)'].dt.year])
anos = anos.values

meses = pd.concat([estacao_ssa_2003['DATA (YYYY-MM-DD)'].dt.month,
                   estacao_ssa_2013['DATA (YYYY-MM-DD)'].dt.month,
                   estacao_ssa_2023['DATA (YYYY-MM-DD)'].dt.month])
meses = meses.values

dias = pd.concat([estacao_ssa_2003['DATA (YYYY-MM-DD)'].dt.day,
                  estacao_ssa_2013['DATA (YYYY-MM-DD)'].dt.day,
                  estacao_ssa_2023['DATA (YYYY-MM-DD)'].dt.day])



# criando indice
index = pd.MultiIndex.from_arrays([anos, meses, dias], names=['ano', 'mes', 'dia'])

# %%
# criando dataframa multiindexado por ano, mes e dia
estacao_ssa = pd.concat([estacao_ssa_2003, estacao_ssa_2013, estacao_ssa_2023]).drop(columns=['DATA (YYYY-MM-DD)', 'HORA (UTC)'])
estacao_ssa.set_index(index, inplace=True)
estacao_ssa
# Out:
#              PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# ano  mes dia
# 2003 1   1                              -9999  \
#          1                              -9999
#          1                              -9999
#          1                              -9999
#          1                              -9999
# ...                                       ...
# 2023 12  31                                 0
#          31                                 0
#          31                                 0
#          31                                 0
#          31                                 0
#
#              PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)
# ano  mes dia
# 2003 1   1                                                -9999     \
#          1                                                -9999
#          1                                                -9999
#          1                                                -9999
#          1                                                -9999
# ...                                                         ...
# 2023 12  31                                              1004,6
#          31                                              1004,8
#          31                                                1005
#          31                                              1005,3
#          31                                              1005,8
#
#              PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)
# ano  mes dia
# 2003 1   1                                             -9999  \
#          1                                             -9999
#          1                                             -9999
#          1                                             -9999
#          1                                             -9999
# ...                                                      ...
# 2023 12  31                                           1005,1
#          31                                           1004,8
#          31                                           1005,1
#          31                                           1005,3
#          31                                           1005,8
#
#              PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)
# ano  mes dia
# 2003 1   1                                              -9999  \
#          1                                              -9999
#          1                                              -9999
#          1                                              -9999
#          1                                              -9999
# ...                                                       ...
# 2023 12  31                                            1004,6
#          31                                            1004,5
#          31                                            1004,8
#          31                                            1004,9
#          31                                            1005,3
#
#              RADIACAO GLOBAL (KJ/m²)
# ano  mes dia
# 2003 1   1                     -9999  \
#          1                     -9999
#          1                     -9999
#          1                     -9999
#          1                     -9999
# ...                              ...
# 2023 12  31                   1641,3
#          31                    644,8
#          31                    148,7
#          31                      NaN
#          31                      NaN
#
#              TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)
# ano  mes dia
# 2003 1   1                                          -9999  \
#          1                                          -9999
#          1                                          -9999
#          1                                          -9999
#          1                                          -9999
# ...                                                   ...
# 2023 12  31                                          29,9
#          31                                          28,4
#          31                                          27,3
#          31                                            27
#          31                                          26,7
#
#              TEMPERATURA DO PONTO DE ORVALHO (°C)
# ano  mes dia
# 2003 1   1                                  -9999  \
#          1                                  -9999
#          1                                  -9999
#          1                                  -9999
#          1                                  -9999
# ...                                           ...
# 2023 12  31                                  21,9
#          31                                  21,9
#          31                                  22,3
#          31                                  22,3
#          31                                  22,7
#
#              TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)
# ano  mes dia
# 2003 1   1                                        -9999  \
#          1                                        -9999
#          1                                        -9999
#          1                                        -9999
#          1                                        -9999
# ...                                                 ...
# 2023 12  31                                        30,9
#          31                                        29,9
#          31                                        28,4
#          31                                        27,3
#          31                                        27,1
#
#              TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)
# ano  mes dia
# 2003 1   1                                        -9999  \
#          1                                        -9999
#          1                                        -9999
#          1                                        -9999
#          1                                        -9999
# ...                                                 ...
# 2023 12  31                                        29,7
#          31                                        28,4
#          31                                        27,3
#          31                                          27
#          31                                        26,7
#
#              TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)
# ano  mes dia
# 2003 1   1                                              -9999  \
#          1                                              -9999
#          1                                              -9999
#          1                                              -9999
#          1                                              -9999
# ...                                                       ...
# 2023 12  31                                              23,1
#          31                                              22,6
#          31                                              22,4
#          31                                              22,3
#          31                                              22,7
#
#              TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)
# ano  mes dia
# 2003 1   1                                              -9999  \
#          1                                              -9999
#          1                                              -9999
#          1                                              -9999
#          1                                              -9999
# ...                                                       ...
# 2023 12  31                                              21,6
#          31                                              21,8
#          31                                              21,8
#          31                                              22,1
#          31                                              22,3
#
#               UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)
# ano  mes dia
# 2003 1   1                                     -9999.0  \
#          1                                     -9999.0
#          1                                     -9999.0
#          1                                     -9999.0
#          1                                     -9999.0
# ...                                                ...
# 2023 12  31                                       64.0
#          31                                       69.0
#          31                                       74.0
#          31                                       75.0
#          31                                       79.0
#
#               UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)
# ano  mes dia
# 2003 1   1                                     -9999.0  \
#          1                                     -9999.0
#          1                                     -9999.0
#          1                                     -9999.0
#          1                                     -9999.0
# ...                                                ...
# 2023 12  31                                       61.0
#          31                                       62.0
#          31                                       68.0
#          31                                       73.0
#          31                                       75.0
#
#               UMIDADE RELATIVA DO AR, HORARIA (%)
# ano  mes dia
# 2003 1   1                                -9999.0  \
#          1                                -9999.0
#          1                                -9999.0
#          1                                -9999.0
#          1                                -9999.0
# ...                                           ...
# 2023 12  31                                  62.0
#          31                                  68.0
#          31                                  74.0
#          31                                  75.0
#          31                                  78.0
#
#               VENTO, DIREÇÃO HORARIA (gr) (° (gr)) VENTO, RAJADA MAXIMA (m/s)
# ano  mes dia
# 2003 1   1                                 -9999.0                      -9999  \
#          1                                 -9999.0                      -9999
#          1                                 -9999.0                      -9999
#          1                                 -9999.0                      -9999
#          1                                 -9999.0                      -9999
# ...                                            ...                        ...
# 2023 12  31                                  106.0                        6,4
#          31                                   91.0                        5,7
#          31                                   80.0                        4,9
#          31                                   65.0                        4,3
#          31                                   74.0                        5,2
#
#              VENTO, VELOCIDADE HORARIA (m/s)
# ano  mes dia
# 2003 1   1                             -9999
#          1                             -9999
#          1                             -9999
#          1                             -9999
#          1                             -9999
# ...                                      ...
# 2023 12  31                              1,2
#          31                              1,6
#          31                              1,3
#          31                                1
#          31                              1,4
#
# [26280 rows x 17 columns]

# %% [markdown]
# 2. Construindo novo ``DataFrame`` utilizando ``MultiIndex`` como colunas contendo os parâmetros agrupados (precipitações, pressão, radiação, temperatura, umidade, velocidade do vento)

# %%
# criando multiindex para as colunas
nivel_1 = ['precipitacao'] + ['pressao']*3 + ['radiacao'] + ['temperatura']*6 + ['umidade']*3 + ['velocidade do vento']*3
nivel_2 = colunas_2003[2:]

# definindo multiindex para as colunas
index_col = pd.MultiIndex.from_arrays([nivel_1, nivel_2], names=['medicao', 'tipo'])

estacao_ssa.columns = index_col
estacao_ssa
# Out:
# medicao                          precipitacao
# tipo         PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# ano  mes dia
# 2003 1   1                              -9999  \
#          1                              -9999
#          1                              -9999
#          1                              -9999
#          1                              -9999
# ...                                       ...
# 2023 12  31                                 0
#          31                                 0
#          31                                 0
#          31                                 0
#          31                                 0
#
# medicao                                                    pressao
# tipo         PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)
# ano  mes dia
# 2003 1   1                                                -9999     \
#          1                                                -9999
#          1                                                -9999
#          1                                                -9999
#          1                                                -9999
# ...                                                         ...
# 2023 12  31                                              1004,6
#          31                                              1004,8
#          31                                                1005
#          31                                              1005,3
#          31                                              1005,8
#
# medicao
# tipo         PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)
# ano  mes dia
# 2003 1   1                                             -9999  \
#          1                                             -9999
#          1                                             -9999
#          1                                             -9999
#          1                                             -9999
# ...                                                      ...
# 2023 12  31                                           1005,1
#          31                                           1004,8
#          31                                           1005,1
#          31                                           1005,3
#          31                                           1005,8
#
# medicao
# tipo         PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)
# ano  mes dia
# 2003 1   1                                              -9999  \
#          1                                              -9999
#          1                                              -9999
#          1                                              -9999
#          1                                              -9999
# ...                                                       ...
# 2023 12  31                                            1004,6
#          31                                            1004,5
#          31                                            1004,8
#          31                                            1004,9
#          31                                            1005,3
#
# medicao                     radiacao
# tipo         RADIACAO GLOBAL (KJ/m²)
# ano  mes dia
# 2003 1   1                     -9999  \
#          1                     -9999
#          1                     -9999
#          1                     -9999
#          1                     -9999
# ...                              ...
# 2023 12  31                   1641,3
#          31                    644,8
#          31                    148,7
#          31                      NaN
#          31                      NaN
#
# medicao                                       temperatura
# tipo         TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)
# ano  mes dia
# 2003 1   1                                          -9999  \
#          1                                          -9999
#          1                                          -9999
#          1                                          -9999
#          1                                          -9999
# ...                                                   ...
# 2023 12  31                                          29,9
#          31                                          28,4
#          31                                          27,3
#          31                                            27
#          31                                          26,7
#
# medicao
# tipo         TEMPERATURA DO PONTO DE ORVALHO (°C)
# ano  mes dia
# 2003 1   1                                  -9999  \
#          1                                  -9999
#          1                                  -9999
#          1                                  -9999
#          1                                  -9999
# ...                                           ...
# 2023 12  31                                  21,9
#          31                                  21,9
#          31                                  22,3
#          31                                  22,3
#          31                                  22,7
#
# medicao
# tipo         TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)
# ano  mes dia
# 2003 1   1                                        -9999  \
#          1                                        -9999
#          1                                        -9999
#          1                                        -9999
#          1                                        -9999
# ...                                                 ...
# 2023 12  31                                        30,9
#          31                                        29,9
#          31                                        28,4
#          31                                        27,3
#          31                                        27,1
#
# medicao
# tipo         TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)
# ano  mes dia
# 2003 1   1                                        -9999  \
#          1                                        -9999
#          1                                        -9999
#          1                                        -9999
#          1                                        -9999
# ...                                                 ...
# 2023 12  31                                        29,7
#          31                                        28,4
#          31                                        27,3
#          31                                          27
#          31                                        26,7
#
# medicao
# tipo         TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)
# ano  mes dia
# 2003 1   1                                              -9999  \
#          1                                              -9999
#          1                                              -9999
#          1                                              -9999
#          1                                              -9999
# ...                                                       ...
# 2023 12  31                                              23,1
#          31                                              22,6
#          31                                              22,4
#          31                                              22,3
#          31                                              22,7
#
# medicao
# tipo         TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)
# ano  mes dia
# 2003 1   1                                              -9999  \
#          1                                              -9999
#          1                                              -9999
#          1                                              -9999
#          1                                              -9999
# ...                                                       ...
# 2023 12  31                                              21,6
#          31                                              21,8
#          31                                              21,8
#          31                                              22,1
#          31                                              22,3
#
# medicao                                       umidade
# tipo         UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)
# ano  mes dia
# 2003 1   1                                    -9999.0  \
#          1                                    -9999.0
#          1                                    -9999.0
#          1                                    -9999.0
#          1                                    -9999.0
# ...                                               ...
# 2023 12  31                                      64.0
#          31                                      69.0
#          31                                      74.0
#          31                                      75.0
#          31                                      79.0
#
# medicao
# tipo         UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)
# ano  mes dia
# 2003 1   1                                    -9999.0  \
#          1                                    -9999.0
#          1                                    -9999.0
#          1                                    -9999.0
#          1                                    -9999.0
# ...                                               ...
# 2023 12  31                                      61.0
#          31                                      62.0
#          31                                      68.0
#          31                                      73.0
#          31                                      75.0
#
# medicao
# tipo         UMIDADE RELATIVA DO AR, HORARIA (%)
# ano  mes dia
# 2003 1   1                               -9999.0  \
#          1                               -9999.0
#          1                               -9999.0
#          1                               -9999.0
#          1                               -9999.0
# ...                                          ...
# 2023 12  31                                 62.0
#          31                                 68.0
#          31                                 74.0
#          31                                 75.0
#          31                                 78.0
#
# medicao                       velocidade do vento
# tipo         VENTO, DIREÇÃO HORARIA (gr) (° (gr)) VENTO, RAJADA MAXIMA (m/s)
# ano  mes dia
# 2003 1   1                                -9999.0                      -9999  \
#          1                                -9999.0                      -9999
#          1                                -9999.0                      -9999
#          1                                -9999.0                      -9999
#          1                                -9999.0                      -9999
# ...                                           ...                        ...
# 2023 12  31                                 106.0                        6,4
#          31                                  91.0                        5,7
#          31                                  80.0                        4,9
#          31                                  65.0                        4,3
#          31                                  74.0                        5,2
#
# medicao
# tipo         VENTO, VELOCIDADE HORARIA (m/s)
# ano  mes dia
# 2003 1   1                             -9999
#          1                             -9999
#          1                             -9999
#          1                             -9999
#          1                             -9999
# ...                                      ...
# 2023 12  31                              1,2
#          31                              1,6
#          31                              1,3
#          31                                1
#          31                              1,4
#
# [26280 rows x 17 columns]

# %% [markdown]
# ### __Exercício 3: Analisando os DataFrame__
#
# * Preparando os dados

# %%
import numpy as np
estacao_ssa.info()
estacao_ssa.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 26280 entries, (2003, 1, 1) to (2023, 12, 31)
# Data columns (total 17 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   (precipitacao, PRECIPITAÇÃO TOTAL, HORÁRIO (mm))                  26276 non-null  object
#  1   (pressao, PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB))  26276 non-null  object
#  2   (pressao, PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB))        26276 non-null  object
#  3   (pressao, PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB))       26276 non-null  object
#  4   (radiacao, RADIACAO GLOBAL (KJ/m²))                               22255 non-null  object
#  5   (temperatura, TEMPERATURA DO AR - BULBO SECO, HORARIA (°C))       26276 non-null  object
#  6   (temperatura, TEMPERATURA DO PONTO DE ORVALHO (°C))               26276 non-null  object
#  7   (temperatura, TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C))         26276 non-null  object
#  8   (temperatura, TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C))         26276 non-null  object
#  9   (temperatura, TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C))   26276 non-null  object
#  10  (temperatura, TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C))   26276 non-null  object
#  11  (umidade, UMIDADE REL. MAX. NA HORA ANT. (AUT) (%))               26276 non-null  float64
#  12  (umidade, UMIDADE REL. MIN. NA HORA ANT. (AUT) (%))               26276 non-null  float64
#  13  (umidade, UMIDADE RELATIVA DO AR, HORARIA (%))                    26276 non-null  float64
#  14  (velocidade do vento, VENTO, DIREÇÃO HORARIA (gr) (° (gr)))       26276 non-null  float64
#  15  (velocidade do vento, VENTO, RAJADA MAXIMA (m/s))                 26276 non-null  object
#  16  (velocidade do vento, VENTO, VELOCIDADE HORARIA (m/s))            26276 non-null  object
# dtypes: float64(4), object(13)
# memory usage: 3.5+ MB
# medicao                          precipitacao
# tipo         PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# ano  mes dia
# 2003 1   1                              -9999  \
#          1                              -9999
#          1                              -9999
#          1                              -9999
#          1                              -9999
#
# medicao                                                    pressao
# tipo         PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)
# ano  mes dia
# 2003 1   1                                                -9999     \
#          1                                                -9999
#          1                                                -9999
#          1                                                -9999
#          1                                                -9999
#
# medicao
# tipo         PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)
# ano  mes dia
# 2003 1   1                                             -9999  \
#          1                                             -9999
#          1                                             -9999
#          1                                             -9999
#          1                                             -9999
#
# medicao
# tipo         PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)
# ano  mes dia
# 2003 1   1                                              -9999  \
#          1                                              -9999
#          1                                              -9999
#          1                                              -9999
#          1                                              -9999
#
# medicao                     radiacao
# tipo         RADIACAO GLOBAL (KJ/m²)
# ano  mes dia
# 2003 1   1                     -9999  \
#          1                     -9999
#          1                     -9999
#          1                     -9999
#          1                     -9999
#
# medicao                                       temperatura
# tipo         TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)
# ano  mes dia
# 2003 1   1                                          -9999  \
#          1                                          -9999
#          1                                          -9999
#          1                                          -9999
#          1                                          -9999
#
# medicao
# tipo         TEMPERATURA DO PONTO DE ORVALHO (°C)
# ano  mes dia
# 2003 1   1                                  -9999  \
#          1                                  -9999
#          1                                  -9999
#          1                                  -9999
#          1                                  -9999
#
# medicao
# tipo         TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)
# ano  mes dia
# 2003 1   1                                        -9999  \
#          1                                        -9999
#          1                                        -9999
#          1                                        -9999
#          1                                        -9999
#
# medicao
# tipo         TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)
# ano  mes dia
# 2003 1   1                                        -9999  \
#          1                                        -9999
#          1                                        -9999
#          1                                        -9999
#          1                                        -9999
#
# medicao
# tipo         TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)
# ano  mes dia
# 2003 1   1                                              -9999  \
#          1                                              -9999
#          1                                              -9999
#          1                                              -9999
#          1                                              -9999
#
# medicao
# tipo         TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)
# ano  mes dia
# 2003 1   1                                              -9999  \
#          1                                              -9999
#          1                                              -9999
#          1                                              -9999
#          1                                              -9999
#
# medicao                                       umidade
# tipo         UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)
# ano  mes dia
# 2003 1   1                                    -9999.0  \
#          1                                    -9999.0
#          1                                    -9999.0
#          1                                    -9999.0
#          1                                    -9999.0
#
# medicao
# tipo         UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)
# ano  mes dia
# 2003 1   1                                    -9999.0  \
#          1                                    -9999.0
#          1                                    -9999.0
#          1                                    -9999.0
#          1                                    -9999.0
#
# medicao
# tipo         UMIDADE RELATIVA DO AR, HORARIA (%)
# ano  mes dia
# 2003 1   1                               -9999.0  \
#          1                               -9999.0
#          1                               -9999.0
#          1                               -9999.0
#          1                               -9999.0
#
# medicao                       velocidade do vento
# tipo         VENTO, DIREÇÃO HORARIA (gr) (° (gr)) VENTO, RAJADA MAXIMA (m/s)
# ano  mes dia
# 2003 1   1                                -9999.0                      -9999  \
#          1                                -9999.0                      -9999
#          1                                -9999.0                      -9999
#          1                                -9999.0                      -9999
#          1                                -9999.0                      -9999
#
# medicao
# tipo         VENTO, VELOCIDADE HORARIA (m/s)
# ano  mes dia
# 2003 1   1                             -9999
#          1                             -9999
#          1                             -9999
#          1                             -9999
#          1                             -9999

# %%
# substituindo valores -9999 por NaN
estacao_ssa.replace(['-9999', -9999, -9999.0, '-9999.0'], value= np.nan, inplace=True)


estacao_ssa
# Out:
# medicao                          precipitacao
# tipo         PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# ano  mes dia
# 2003 1   1                                NaN  \
#          1                                NaN
#          1                                NaN
#          1                                NaN
#          1                                NaN
# ...                                       ...
# 2023 12  31                                 0
#          31                                 0
#          31                                 0
#          31                                 0
#          31                                 0
#
# medicao                                                    pressao
# tipo         PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)
# ano  mes dia
# 2003 1   1                                                  NaN     \
#          1                                                  NaN
#          1                                                  NaN
#          1                                                  NaN
#          1                                                  NaN
# ...                                                         ...
# 2023 12  31                                              1004,6
#          31                                              1004,8
#          31                                                1005
#          31                                              1005,3
#          31                                              1005,8
#
# medicao
# tipo         PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)
# ano  mes dia
# 2003 1   1                                               NaN  \
#          1                                               NaN
#          1                                               NaN
#          1                                               NaN
#          1                                               NaN
# ...                                                      ...
# 2023 12  31                                           1005,1
#          31                                           1004,8
#          31                                           1005,1
#          31                                           1005,3
#          31                                           1005,8
#
# medicao
# tipo         PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)
# ano  mes dia
# 2003 1   1                                                NaN  \
#          1                                                NaN
#          1                                                NaN
#          1                                                NaN
#          1                                                NaN
# ...                                                       ...
# 2023 12  31                                            1004,6
#          31                                            1004,5
#          31                                            1004,8
#          31                                            1004,9
#          31                                            1005,3
#
# medicao                     radiacao
# tipo         RADIACAO GLOBAL (KJ/m²)
# ano  mes dia
# 2003 1   1                       NaN  \
#          1                       NaN
#          1                       NaN
#          1                       NaN
#          1                       NaN
# ...                              ...
# 2023 12  31                   1641,3
#          31                    644,8
#          31                    148,7
#          31                      NaN
#          31                      NaN
#
# medicao                                       temperatura
# tipo         TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)
# ano  mes dia
# 2003 1   1                                            NaN  \
#          1                                            NaN
#          1                                            NaN
#          1                                            NaN
#          1                                            NaN
# ...                                                   ...
# 2023 12  31                                          29,9
#          31                                          28,4
#          31                                          27,3
#          31                                            27
#          31                                          26,7
#
# medicao
# tipo         TEMPERATURA DO PONTO DE ORVALHO (°C)
# ano  mes dia
# 2003 1   1                                    NaN  \
#          1                                    NaN
#          1                                    NaN
#          1                                    NaN
#          1                                    NaN
# ...                                           ...
# 2023 12  31                                  21,9
#          31                                  21,9
#          31                                  22,3
#          31                                  22,3
#          31                                  22,7
#
# medicao
# tipo         TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)
# ano  mes dia
# 2003 1   1                                          NaN  \
#          1                                          NaN
#          1                                          NaN
#          1                                          NaN
#          1                                          NaN
# ...                                                 ...
# 2023 12  31                                        30,9
#          31                                        29,9
#          31                                        28,4
#          31                                        27,3
#          31                                        27,1
#
# medicao
# tipo         TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)
# ano  mes dia
# 2003 1   1                                          NaN  \
#          1                                          NaN
#          1                                          NaN
#          1                                          NaN
#          1                                          NaN
# ...                                                 ...
# 2023 12  31                                        29,7
#          31                                        28,4
#          31                                        27,3
#          31                                          27
#          31                                        26,7
#
# medicao
# tipo         TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)
# ano  mes dia
# 2003 1   1                                                NaN  \
#          1                                                NaN
#          1                                                NaN
#          1                                                NaN
#          1                                                NaN
# ...                                                       ...
# 2023 12  31                                              23,1
#          31                                              22,6
#          31                                              22,4
#          31                                              22,3
#          31                                              22,7
#
# medicao
# tipo         TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)
# ano  mes dia
# 2003 1   1                                                NaN  \
#          1                                                NaN
#          1                                                NaN
#          1                                                NaN
#          1                                                NaN
# ...                                                       ...
# 2023 12  31                                              21,6
#          31                                              21,8
#          31                                              21,8
#          31                                              22,1
#          31                                              22,3
#
# medicao                                       umidade
# tipo         UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)
# ano  mes dia
# 2003 1   1                                        NaN  \
#          1                                        NaN
#          1                                        NaN
#          1                                        NaN
#          1                                        NaN
# ...                                               ...
# 2023 12  31                                      64.0
#          31                                      69.0
#          31                                      74.0
#          31                                      75.0
#          31                                      79.0
#
# medicao
# tipo         UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)
# ano  mes dia
# 2003 1   1                                        NaN  \
#          1                                        NaN
#          1                                        NaN
#          1                                        NaN
#          1                                        NaN
# ...                                               ...
# 2023 12  31                                      61.0
#          31                                      62.0
#          31                                      68.0
#          31                                      73.0
#          31                                      75.0
#
# medicao
# tipo         UMIDADE RELATIVA DO AR, HORARIA (%)
# ano  mes dia
# 2003 1   1                                   NaN  \
#          1                                   NaN
#          1                                   NaN
#          1                                   NaN
#          1                                   NaN
# ...                                          ...
# 2023 12  31                                 62.0
#          31                                 68.0
#          31                                 74.0
#          31                                 75.0
#          31                                 78.0
#
# medicao                       velocidade do vento
# tipo         VENTO, DIREÇÃO HORARIA (gr) (° (gr)) VENTO, RAJADA MAXIMA (m/s)
# ano  mes dia
# 2003 1   1                                    NaN                        NaN  \
#          1                                    NaN                        NaN
#          1                                    NaN                        NaN
#          1                                    NaN                        NaN
#          1                                    NaN                        NaN
# ...                                           ...                        ...
# 2023 12  31                                 106.0                        6,4
#          31                                  91.0                        5,7
#          31                                  80.0                        4,9
#          31                                  65.0                        4,3
#          31                                  74.0                        5,2
#
# medicao
# tipo         VENTO, VELOCIDADE HORARIA (m/s)
# ano  mes dia
# 2003 1   1                               NaN
#          1                               NaN
#          1                               NaN
#          1                               NaN
#          1                               NaN
# ...                                      ...
# 2023 12  31                              1,2
#          31                              1,6
#          31                              1,3
#          31                                1
#          31                              1,4
#
# [26280 rows x 17 columns]

# %%
# tratando precipitacao
print(estacao_ssa['precipitacao']['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'].unique())

# substiduindo valores , por .
estacao_ssa.loc[:, ('precipitacao', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)')].replace(',', '.', regex=True, inplace=True)

# convertendo para float
estacao_ssa['precipitacao'] = estacao_ssa['precipitacao'].astype('float64')

# preenchendo valores NaN com valor anteriores
estacao_ssa.loc[:, ('precipitacao', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)')].bfill(inplace=True)
# Out:
# [nan '0' ',2' '6' ',4' '4,8' '6,4' '1,4' '2,4' '1' ',6' '3' '21,8' '2,2'
#  '6,8' ',8' '2,6' '4,6' '3,4' '8,4' '1,2' '1,8' '15,8' '12,4' '13,8' '4'
#  '10,2' '2' '7,6' '1,6' '3,6' '3,2' '3,8' '4,2' '5,2' '5,8' '10,6' '6,2'
#  '5,6' '9,6' '18,4' '7,4' '18' '16,2' '2,8' '5' '11,6' '10,4' '14,4' '52'
#  '19' '24,4' '13' '21,6' '12,8' '17,6' '18,2' '11,8' '9' '9,4' '8,8' '22'
#  '7,8' '8' '10' '11,2' '5,4' '12,2' '14,6' '7' '4,4' '12' '6,6' '15,2'
#  '9,2' '13,2' '29,4' '7,2' '13,6' '0,8' '0,2' '0,4' '0,6' '9,8' '32,4'
#  '20,6' '8,6' '16,6' '23,8' '14,2' '32,8' '12,6' '13,4' '11' '17' '15,6'
#  '20,4' '17,2' '44,4' '16' '25' '16,8' '14' '8,2' '31,6' '24,2' '22,4'
#  '16,4' '27,6' '38,4']

# %%
# tratando temperaturas
print(np.unique(estacao_ssa['temperatura'].values.astype('str')))
colunas = estacao_ssa['temperatura'].columns.values.tolist()

# substiduindo valores , por .
for coluna in colunas:
    estacao_ssa.loc[:, ('temperatura', coluna)].replace(',', '.', regex=True, inplace=True)

# convertendo para float
estacao_ssa['temperatura'] = estacao_ssa['temperatura'].astype('float64')

# preenchendo valores NaN com valor anteriores
for coluna in colunas:
    estacao_ssa.loc[:, ('temperatura', coluna)].bfill(inplace=True)
# Out:
# ['-1,8' '13,6' '14,2' '14,4' '14,6' '14,7' '14,8' '14,9' '15' '15,1'
#  '15,2' '15,3' '15,4' '15,5' '15,6' '15,7' '15,8' '15,9' '16' '16,1'
#  '16,2' '16,3' '16,4' '16,5' '16,6' '16,7' '16,8' '16,9' '17' '17,1'
#  '17,2' '17,3' '17,4' '17,5' '17,6' '17,7' '17,8' '17,9' '18' '18,1'
#  '18,2' '18,3' '18,4' '18,5' '18,6' '18,7' '18,8' '18,9' '19' '19,1'
#  '19,2' '19,3' '19,4' '19,5' '19,6' '19,7' '19,8' '19,9' '20' '20,1'
#  '20,2' '20,3' '20,4' '20,5' '20,6' '20,7' '20,8' '20,9' '21' '21,1'
#  '21,2' '21,3' '21,4' '21,5' '21,6' '21,7' '21,8' '21,9' '22' '22,1'
#  '22,2' '22,3' '22,4' '22,5' '22,6' '22,7' '22,8' '22,9' '23' '23,1'
#  '23,2' '23,3' '23,4' '23,5' '23,6' '23,7' '23,8' '23,9' '24' '24,1'
#  '24,2' '24,3' '24,4' '24,5' '24,6' '24,7' '24,8' '24,9' '25' '25,1'
#  '25,2' '25,3' '25,4' '25,5' '25,6' '25,7' '25,8' '25,9' '26' '26,1'
#  '26,2' '26,3' '26,4' '26,5' '26,6' '26,7' '26,8' '26,9' '27' '27,1'
#  '27,2' '27,3' '27,4' '27,5' '27,6' '27,7' '27,8' '27,9' '28' '28,1'
#  '28,2' '28,3' '28,4' '28,5' '28,6' '28,7' '28,8' '28,9' '29' '29,1'
#  '29,2' '29,3' '29,4' '29,5' '29,6' '29,7' '29,8' '29,9' '30' '30,1'
#  '30,2' '30,3' '30,4' '30,5' '30,6' '30,7' '30,8' '30,9' '31' '31,1'
#  '31,2' '31,3' '31,4' '31,5' '31,6' '31,7' '31,8' '31,9' '32' '32,1'
#  '32,2' '32,3' '32,4' '32,5' '32,6' '32,7' '32,8' '32,9' '33' '33,1'
#  '33,2' '33,3' '33,4' '33,5' '33,6' '33,7' '33,8' '33,9' '34' '34,1'
#  '34,2' '34,4' '34,6' '35,7' '36,7' '39,7' '41,6' '43,3' 'nan']

# %% [markdown]
# 1. Analisando as colunas relacionadas a precipitações e temperaturas.

# %%
# media de precipitacao por ano
precipitao_temp_ano = estacao_ssa[['precipitacao', 'temperatura']].groupby('ano')
precipitao_temp_ano.aggregate(['min', 'mean', 'max'])
# Out:
# medicao                                  temperatura
# tipo    TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)
#                                                  min       mean   max
# ano
# 2003                                            20.3  25.889817  39.7  \
# 2013                                            19.5  25.677763  34.1
# 2023                                            20.5  26.034920  33.8
#
# medicao
# tipo    TEMPERATURA DO PONTO DE ORVALHO (°C)
#                                          min       mean   max
# ano
# 2003                                    14.7  21.504703  26.6  \
# 2013                                    17.4  21.659897  26.0
# 2023                                    15.2  21.874703  26.2
#
# medicao
# tipo    TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)
#                                                min       mean   max
# ano
# 2003                                          20.7  26.350639  43.3  \
# 2013                                          20.1  26.226507  34.6
# 2023                                          20.7  26.533836  34.1
#
# medicao                                             ...
# tipo    TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  ...
#                                                min  ...   max
# ano                                                 ...
# 2003                                          20.2  ...  33.0  \
# 2013                                          19.3  ...  32.5
# 2023                                          20.5  ...  32.4
#
# medicao
# tipo    TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)
#                                                      min       mean   max
# ano
# 2003                                                15.3  22.000183  26.7  \
# 2013                                                18.0  22.098870  26.8
# 2023                                                16.2  22.332648  27.4
#
# medicao
# tipo    TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)
#                                                      min       mean   max
# ano
# 2003                                                13.6  21.115331  24.7  \
# 2013                                                -1.8  21.150080  24.5
# 2023                                                14.8  21.419315  25.1
#
# medicao                     precipitacao
# tipo    PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
#                                      min      mean   max
# ano
# 2003                                 0.0  0.232420  52.0
# 2013                                 0.0  0.201233  52.0
# 2023                                 0.0  0.174703  38.4
#
# [3 rows x 21 columns]

# %% [markdown]
# 2. Comparando dados para o mes de Janeiro.

# %% [markdown]
# 3. Comparando as informações sobre temperatura e precipitações medias em cada uma das estações dos três anos.

# %% [markdown]
# 4. Comparando informações sobre temperatura e precipitações medias para o dia 28 de setembro  em cada um dos intervalos do dia dos três anos.
